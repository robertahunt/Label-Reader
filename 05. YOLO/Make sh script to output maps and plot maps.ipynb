# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from glob import glob

# %%
with open('get_darknet_maps.sh','w') as f:
    for train_val in ['train','val']:
        for weights in range(100,15000,100):
            f.write('./darknet detector map /home/rob/HWR/darknet/word_%s.data /home/rob/HWR/darknet/cfg/word-yolov3-tiny.cfg aarandzoo/word-yolov3-tiny_%s.weights > maps/%s_%s.txt\n'%(train_val,weights,train_val,weights))

# %%
fps = glob('/home/rob/HWR/darknet/maps/*.txt')
data = []
for fp in fps:
    dataset = fp.split('/')[-1].split('_')[0]
    weights = int(fp.split(dataset + '_')[1].split('.txt')[0])
    with open(fp,'r') as f:
        for line in f.readlines():
            if 'mean average precision' in line:
                _map = float('0.' + re.findall('[0-9]+',line)[1])
                data += [[dataset, weights, _map]]
                
data = pd.DataFrame(data,columns=['dataset','weight','mAP']).sort_values(['dataset','weight'])
data['weight'] = data['weight']*24/4000
plt.figure()
plt.title('YOLO Mean Average Precision (validation set) During Training')
plt.ylabel('mAP')
plt.xlabel('Epoch')
for dataset in ['val']:#data['dataset'].drop_duplicates().values:
    plt.plot(data[(data['dataset']==dataset)&(data['weight'] < 20000)]['weight'],data[(data['dataset']==dataset)&(data['weight'] < 20000)]['mAP'],label=dataset)

#plt.legend()

# %%
data[data['weight']>=34]
# Out:
#     dataset  weight       mAP
# 163   train    34.2  0.889108
# 203   train    34.8  0.897015
# 47    train    35.4  0.879939
# 228   train    36.0  0.889715
# 26    train    36.6  0.857471
# 221   train    37.2  0.888982
# 98    train    37.8  0.869529
# 105   train    38.4  0.892954
# 15    train    39.0  0.880384
# 162   train    39.6  0.874577
# 141   train    40.2  0.853320
# 84    train    40.8  0.886172
# 288   train    41.4  0.898097
# 289   train    42.0  0.888698
# 116   train    42.6  0.895618
# 270   train    43.2  0.898098
# 90    train    43.8  0.895243
# 75    train    44.4  0.879938
# 193   train    45.0  0.899353
# 271   train    45.6  0.898587
# 266   train    46.2  0.889054
# 73    train    46.8  0.889208
# 230   train    47.4  0.891029
# 234   train    48.0  0.897261
# 118   train    48.6  0.888843
# 128   train    49.2  0.897218
# 264   train    49.8  0.892317
# 143   train    50.4  0.879703
# 246   train    51.0  0.894488
# 2     train    51.6  0.894069
# ..      ...     ...       ...
# 56      val    72.0  0.896185
# 269     val    72.6  0.901603
# 275     val    73.2  0.880677
# 284     val    73.8  0.890502
# 191     val    74.4  0.889705
# 114     val    75.0  0.892619
# 194     val    75.6  0.897183
# 244     val    76.2  0.900089
# 40      val    76.8  0.899212
# 195     val    77.4  0.897557
# 296     val    78.0  0.891306
# 100     val    78.6  0.886292
# 247     val    79.2  0.902332
# 176     val    79.8  0.771227
# 74      val    80.4  0.894905
# 9       val    81.0  0.900311
# 255     val    81.6  0.900737
# 291     val    82.2  0.882506
# 6       val    82.8  0.917865
# 256     val    83.4  0.885748
# 192     val    84.0  0.892539
# 44      val    84.6  0.862696
# 59      val    85.2  0.894654
# 17      val    85.8  0.883123
# 240     val    86.4  0.898098
# 65      val    87.0  0.901326
# 96      val    87.6  0.899881
# 20      val    88.2  0.899600
# 180     val    88.8  0.886511
# 218     val    89.4  0.892094
#
# [186 rows x 3 columns]

# %%
#7600 seems good.

# %%
fps = glob('/home/rob/HWR/datasets/Aarhus/*-lab.jpg')
fps += glob('/home/rob/HWR/datasets/zooniverse/*/Cropped*.jpg')
np.random.seed(42)
fps = np.random.permutation(fps)
#60,20,20
#train = fps[:int(len(fps)*0.7)]
#val = fps[int(len(fps)*0.7):]
#test = fps[int(len(fps)*0.8):]
np.savetxt('cropped_to_predict_on.txt',fps,fmt='%s',delimiter='\n')
