# %%
import os
import cv2
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from glob import glob
from tqdm import tqdm_notebook as tqdm

# %%
fig=plt.figure(figsize=(20, 15))
columns = 4
rows = 5
n_images = columns*rows


folderGlob = '/home/rob/HWR/datasets/zooniverse/**/Blank00*.jpg'
fps = glob(folderGlob)

sample = np.random.permutation(fps)

for i in tqdm(range(1, n_images +1)):
    fp = sample[i-1]
    img = cv2.resize(cv2.imread(fp),(160,120))
    fig.add_subplot(rows, columns, i)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(fp.split('/')[6])
plt.show()
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))

# %%
fps
# Out:
# ['/home/rob/HWR/datasets/zooniverse/221846/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222484/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/219991/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222485/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221749/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222459/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220590/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220903/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221013/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220239/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220933/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/223164/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220320/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221547/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/219685/Blank0024.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220765/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220006/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221985/Blank0024.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222497/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221911/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220537/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221629/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222773/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/223197/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220538/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221273/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221365/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222903/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221600/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222268/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221338/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221421/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221681/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221986/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/219476/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/223073/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221808/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/219441/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221818/Blank0024.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222771/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220002/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220993/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221837/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222131/Blank0020.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222296/Blank0025.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221805/Blank0021.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220552/Blank0023.jpg',
#  '/home/rob/HWR/datasets/zooniverse/221336/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/220717/Blank0022.jpg',
#  '/home/rob/HWR/datasets/zooniverse/222676/Blank0022.jpg']
